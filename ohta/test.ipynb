# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t, x_bullet, y_bullet, x_monkey, y_monkey = np.loadtxt('monkey_hunting.txt', unpack=True)

# %%
plt.scatter(x_bullet, y_bullet)
plt.scatter(x_monkey, y_monkey)
